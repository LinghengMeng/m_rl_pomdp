# %% [markdown]
# # Generate and Submit Jobs

# %%
import os
import numpy as np
import pandas as pd
import shutil

# %%
CPU_NUM = 1
JOB_TIME = '0-12:00'
JOB_MEMORY = '10G'
job_dir = '/scratch/lingheng/mrl_job_scripts'              # job script folder
job_out_dir = '/scratch/lingheng/mrl_job_scripts_output'   # job output folder
data_dir = '/scratch/lingheng/mrl_data'    # experiment data folder

# %%
if not os.path.exists(job_dir):
    os.makedirs(job_dir)
if not os.path.exists(job_out_dir):
    os.makedirs(job_out_dir)
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
task_list = ['HalfCheetah-v4', 'Ant-v4', 'Walker2d-v4', 'Hopper-v4']
dp_type_list = ['MDP', 'POMDP-RV', 'POMDP-FLK', 'POMDP-RN', 'POMDP-RSM']
alg_list = ['PPO', 'SAC', 'MSAC', 'TD3', 'MTD3', 'LSTM-TD3']
seed_list = ['0', '1', '2', '3']

# %%
for task in task_list:
    print(task)
    for dp_type in dp_type_list:
        print('\t{}'.format(dp_type))
        for alg in alg_list:
            print('\t\t{}'.format(alg))
            for seed in seed_list:
                exp_name = '{0}_{1}_{2}_{3}'.format(task, dp_type, alg, seed)
                job_filename = 'job_{0}_{1}_{2}_{3}.sh'.format(task, dp_type, alg, seed)
                print('\t\t\t{}: {}'.format(seed, job_filename))
                with open(os.path.join(job_dir, job_filename), 'w') as job_file:
                    job_file.write('#!/bin/bash\n')
                    job_file.write('#SBATCH --account=def-rgorbet\n')
                    job_file.write('#SBATCH --cpus-per-task={}    #Maximum of CPU cores per GPU request: 6 on Cedar, 16 on Graham.\n'.format(CPU_NUM))
                    job_file.write('#SBATCH --mem={}               # memory per node\n'.format(JOB_MEMORY))
                    job_file.write('#SBATCH --time={}            # time (DD-HH:MM)\n'.format(JOB_TIME))
                    job_file.write('#SBATCH --output={0}/job_{1}_{2}_{3}_{4}_%N-%j.out        # %N for node name, %j for jobID\n'.format(job_out_dir, task, dp_type, alg, seed))
                    job_file.write('## Main processing command\n')
                    job_file.write('module load StdEnv/2020  gcc/11.3.0 cuda/11.8.0 python/3.10\n')
                    job_file.write('source ~/m_rl_env/bin/activate\n')
                    job_file.write('python ~/projects/def-rgorbet/lingheng/m_rl_pomdp/m_rl/learn.py --env_id {0} --env_dp_type {1} --rl_agent {2} --seed {3} --exp_name {4} --data_dir {5}'.format(task, dp_type, alg, seed, exp_name, data_dir))
# Out:
# HalfCheetah-v4
# 	MDP
# 		PPO
# 			0: job_HalfCheetah-v4_MDP_PPO_0.sh
# 			1: job_HalfCheetah-v4_MDP_PPO_1.sh
# 			2: job_HalfCheetah-v4_MDP_PPO_2.sh
# 			3: job_HalfCheetah-v4_MDP_PPO_3.sh
# 		SAC
# 			0: job_HalfCheetah-v4_MDP_SAC_0.sh
# 			1: job_HalfCheetah-v4_MDP_SAC_1.sh
# 			2: job_HalfCheetah-v4_MDP_SAC_2.sh
# 			3: job_HalfCheetah-v4_MDP_SAC_3.sh
# 		MSAC
# 			0: job_HalfCheetah-v4_MDP_MSAC_0.sh
# 			1: job_HalfCheetah-v4_MDP_MSAC_1.sh
# 			2: job_HalfCheetah-v4_MDP_MSAC_2.sh
# 			3: job_HalfCheetah-v4_MDP_MSAC_3.sh
# 		TD3
# 			0: job_HalfCheetah-v4_MDP_TD3_0.sh
# 			1: job_HalfCheetah-v4_MDP_TD3_1.sh
# 			2: job_HalfCheetah-v4_MDP_TD3_2.sh
# 			3: job_HalfCheetah-v4_MDP_TD3_3.sh
# 		MTD3
# 			0: job_HalfCheetah-v4_MDP_MTD3_0.sh
# 			1: job_HalfCheetah-v4_MDP_MTD3_1.sh
# 			2: job_HalfCheetah-v4_MDP_MTD3_2.sh
# 			3: job_HalfCheetah-v4_MDP_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_HalfCheetah-v4_MDP_LSTM-TD3_0.sh
# 			1: job_HalfCheetah-v4_MDP_LSTM-TD3_1.sh
# 			2: job_HalfCheetah-v4_MDP_LSTM-TD3_2.sh
# 			3: job_HalfCheetah-v4_MDP_LSTM-TD3_3.sh
# 	POMDP-RV
# 		PPO
# 			0: job_HalfCheetah-v4_POMDP-RV_PPO_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RV_PPO_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RV_PPO_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RV_PPO_3.sh
# 		SAC
# 			0: job_HalfCheetah-v4_POMDP-RV_SAC_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RV_SAC_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RV_SAC_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RV_SAC_3.sh
# 		MSAC
# 			0: job_HalfCheetah-v4_POMDP-RV_MSAC_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RV_MSAC_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RV_MSAC_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RV_MSAC_3.sh
# 		TD3
# 			0: job_HalfCheetah-v4_POMDP-RV_TD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RV_TD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RV_TD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RV_TD3_3.sh
# 		MTD3
# 			0: job_HalfCheetah-v4_POMDP-RV_MTD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RV_MTD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RV_MTD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RV_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_HalfCheetah-v4_POMDP-RV_LSTM-TD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RV_LSTM-TD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RV_LSTM-TD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RV_LSTM-TD3_3.sh
# 	POMDP-FLK
# 		PPO
# 			0: job_HalfCheetah-v4_POMDP-FLK_PPO_0.sh
# 			1: job_HalfCheetah-v4_POMDP-FLK_PPO_1.sh
# 			2: job_HalfCheetah-v4_POMDP-FLK_PPO_2.sh
# 			3: job_HalfCheetah-v4_POMDP-FLK_PPO_3.sh
# 		SAC
# 			0: job_HalfCheetah-v4_POMDP-FLK_SAC_0.sh
# 			1: job_HalfCheetah-v4_POMDP-FLK_SAC_1.sh
# 			2: job_HalfCheetah-v4_POMDP-FLK_SAC_2.sh
# 			3: job_HalfCheetah-v4_POMDP-FLK_SAC_3.sh
# 		MSAC
# 			0: job_HalfCheetah-v4_POMDP-FLK_MSAC_0.sh
# 			1: job_HalfCheetah-v4_POMDP-FLK_MSAC_1.sh
# 			2: job_HalfCheetah-v4_POMDP-FLK_MSAC_2.sh
# 			3: job_HalfCheetah-v4_POMDP-FLK_MSAC_3.sh
# 		TD3
# 			0: job_HalfCheetah-v4_POMDP-FLK_TD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-FLK_TD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-FLK_TD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-FLK_TD3_3.sh
# 		MTD3
# 			0: job_HalfCheetah-v4_POMDP-FLK_MTD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-FLK_MTD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-FLK_MTD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-FLK_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_3.sh
# 	POMDP-RN
# 		PPO
# 			0: job_HalfCheetah-v4_POMDP-RN_PPO_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RN_PPO_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RN_PPO_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RN_PPO_3.sh
# 		SAC
# 			0: job_HalfCheetah-v4_POMDP-RN_SAC_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RN_SAC_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RN_SAC_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RN_SAC_3.sh
# 		MSAC
# 			0: job_HalfCheetah-v4_POMDP-RN_MSAC_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RN_MSAC_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RN_MSAC_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RN_MSAC_3.sh
# 		TD3
# 			0: job_HalfCheetah-v4_POMDP-RN_TD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RN_TD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RN_TD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RN_TD3_3.sh
# 		MTD3
# 			0: job_HalfCheetah-v4_POMDP-RN_MTD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RN_MTD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RN_MTD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RN_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_HalfCheetah-v4_POMDP-RN_LSTM-TD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RN_LSTM-TD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RN_LSTM-TD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RN_LSTM-TD3_3.sh
# 	POMDP-RSM
# 		PPO
# 			0: job_HalfCheetah-v4_POMDP-RSM_PPO_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RSM_PPO_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RSM_PPO_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RSM_PPO_3.sh
# 		SAC
# 			0: job_HalfCheetah-v4_POMDP-RSM_SAC_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RSM_SAC_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RSM_SAC_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RSM_SAC_3.sh
# 		MSAC
# 			0: job_HalfCheetah-v4_POMDP-RSM_MSAC_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RSM_MSAC_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RSM_MSAC_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RSM_MSAC_3.sh
# 		TD3
# 			0: job_HalfCheetah-v4_POMDP-RSM_TD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RSM_TD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RSM_TD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RSM_TD3_3.sh
# 		MTD3
# 			0: job_HalfCheetah-v4_POMDP-RSM_MTD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RSM_MTD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RSM_MTD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RSM_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_0.sh
# 			1: job_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_1.sh
# 			2: job_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_2.sh
# 			3: job_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_3.sh
# Ant-v4
# 	MDP
# 		PPO
# 			0: job_Ant-v4_MDP_PPO_0.sh
# 			1: job_Ant-v4_MDP_PPO_1.sh
# 			2: job_Ant-v4_MDP_PPO_2.sh
# 			3: job_Ant-v4_MDP_PPO_3.sh
# 		SAC
# 			0: job_Ant-v4_MDP_SAC_0.sh
# 			1: job_Ant-v4_MDP_SAC_1.sh
# 			2: job_Ant-v4_MDP_SAC_2.sh
# 			3: job_Ant-v4_MDP_SAC_3.sh
# 		MSAC
# 			0: job_Ant-v4_MDP_MSAC_0.sh
# 			1: job_Ant-v4_MDP_MSAC_1.sh
# 			2: job_Ant-v4_MDP_MSAC_2.sh
# 			3: job_Ant-v4_MDP_MSAC_3.sh
# 		TD3
# 			0: job_Ant-v4_MDP_TD3_0.sh
# 			1: job_Ant-v4_MDP_TD3_1.sh
# 			2: job_Ant-v4_MDP_TD3_2.sh
# 			3: job_Ant-v4_MDP_TD3_3.sh
# 		MTD3
# 			0: job_Ant-v4_MDP_MTD3_0.sh
# 			1: job_Ant-v4_MDP_MTD3_1.sh
# 			2: job_Ant-v4_MDP_MTD3_2.sh
# 			3: job_Ant-v4_MDP_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Ant-v4_MDP_LSTM-TD3_0.sh
# 			1: job_Ant-v4_MDP_LSTM-TD3_1.sh
# 			2: job_Ant-v4_MDP_LSTM-TD3_2.sh
# 			3: job_Ant-v4_MDP_LSTM-TD3_3.sh
# 	POMDP-RV
# 		PPO
# 			0: job_Ant-v4_POMDP-RV_PPO_0.sh
# 			1: job_Ant-v4_POMDP-RV_PPO_1.sh
# 			2: job_Ant-v4_POMDP-RV_PPO_2.sh
# 			3: job_Ant-v4_POMDP-RV_PPO_3.sh
# 		SAC
# 			0: job_Ant-v4_POMDP-RV_SAC_0.sh
# 			1: job_Ant-v4_POMDP-RV_SAC_1.sh
# 			2: job_Ant-v4_POMDP-RV_SAC_2.sh
# 			3: job_Ant-v4_POMDP-RV_SAC_3.sh
# 		MSAC
# 			0: job_Ant-v4_POMDP-RV_MSAC_0.sh
# 			1: job_Ant-v4_POMDP-RV_MSAC_1.sh
# 			2: job_Ant-v4_POMDP-RV_MSAC_2.sh
# 			3: job_Ant-v4_POMDP-RV_MSAC_3.sh
# 		TD3
# 			0: job_Ant-v4_POMDP-RV_TD3_0.sh
# 			1: job_Ant-v4_POMDP-RV_TD3_1.sh
# 			2: job_Ant-v4_POMDP-RV_TD3_2.sh
# 			3: job_Ant-v4_POMDP-RV_TD3_3.sh
# 		MTD3
# 			0: job_Ant-v4_POMDP-RV_MTD3_0.sh
# 			1: job_Ant-v4_POMDP-RV_MTD3_1.sh
# 			2: job_Ant-v4_POMDP-RV_MTD3_2.sh
# 			3: job_Ant-v4_POMDP-RV_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Ant-v4_POMDP-RV_LSTM-TD3_0.sh
# 			1: job_Ant-v4_POMDP-RV_LSTM-TD3_1.sh
# 			2: job_Ant-v4_POMDP-RV_LSTM-TD3_2.sh
# 			3: job_Ant-v4_POMDP-RV_LSTM-TD3_3.sh
# 	POMDP-FLK
# 		PPO
# 			0: job_Ant-v4_POMDP-FLK_PPO_0.sh
# 			1: job_Ant-v4_POMDP-FLK_PPO_1.sh
# 			2: job_Ant-v4_POMDP-FLK_PPO_2.sh
# 			3: job_Ant-v4_POMDP-FLK_PPO_3.sh
# 		SAC
# 			0: job_Ant-v4_POMDP-FLK_SAC_0.sh
# 			1: job_Ant-v4_POMDP-FLK_SAC_1.sh
# 			2: job_Ant-v4_POMDP-FLK_SAC_2.sh
# 			3: job_Ant-v4_POMDP-FLK_SAC_3.sh
# 		MSAC
# 			0: job_Ant-v4_POMDP-FLK_MSAC_0.sh
# 			1: job_Ant-v4_POMDP-FLK_MSAC_1.sh
# 			2: job_Ant-v4_POMDP-FLK_MSAC_2.sh
# 			3: job_Ant-v4_POMDP-FLK_MSAC_3.sh
# 		TD3
# 			0: job_Ant-v4_POMDP-FLK_TD3_0.sh
# 			1: job_Ant-v4_POMDP-FLK_TD3_1.sh
# 			2: job_Ant-v4_POMDP-FLK_TD3_2.sh
# 			3: job_Ant-v4_POMDP-FLK_TD3_3.sh
# 		MTD3
# 			0: job_Ant-v4_POMDP-FLK_MTD3_0.sh
# 			1: job_Ant-v4_POMDP-FLK_MTD3_1.sh
# 			2: job_Ant-v4_POMDP-FLK_MTD3_2.sh
# 			3: job_Ant-v4_POMDP-FLK_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Ant-v4_POMDP-FLK_LSTM-TD3_0.sh
# 			1: job_Ant-v4_POMDP-FLK_LSTM-TD3_1.sh
# 			2: job_Ant-v4_POMDP-FLK_LSTM-TD3_2.sh
# 			3: job_Ant-v4_POMDP-FLK_LSTM-TD3_3.sh
# 	POMDP-RN
# 		PPO
# 			0: job_Ant-v4_POMDP-RN_PPO_0.sh
# 			1: job_Ant-v4_POMDP-RN_PPO_1.sh
# 			2: job_Ant-v4_POMDP-RN_PPO_2.sh
# 			3: job_Ant-v4_POMDP-RN_PPO_3.sh
# 		SAC
# 			0: job_Ant-v4_POMDP-RN_SAC_0.sh
# 			1: job_Ant-v4_POMDP-RN_SAC_1.sh
# 			2: job_Ant-v4_POMDP-RN_SAC_2.sh
# 			3: job_Ant-v4_POMDP-RN_SAC_3.sh
# 		MSAC
# 			0: job_Ant-v4_POMDP-RN_MSAC_0.sh
# 			1: job_Ant-v4_POMDP-RN_MSAC_1.sh
# 			2: job_Ant-v4_POMDP-RN_MSAC_2.sh
# 			3: job_Ant-v4_POMDP-RN_MSAC_3.sh
# 		TD3
# 			0: job_Ant-v4_POMDP-RN_TD3_0.sh
# 			1: job_Ant-v4_POMDP-RN_TD3_1.sh
# 			2: job_Ant-v4_POMDP-RN_TD3_2.sh
# 			3: job_Ant-v4_POMDP-RN_TD3_3.sh
# 		MTD3
# 			0: job_Ant-v4_POMDP-RN_MTD3_0.sh
# 			1: job_Ant-v4_POMDP-RN_MTD3_1.sh
# 			2: job_Ant-v4_POMDP-RN_MTD3_2.sh
# 			3: job_Ant-v4_POMDP-RN_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Ant-v4_POMDP-RN_LSTM-TD3_0.sh
# 			1: job_Ant-v4_POMDP-RN_LSTM-TD3_1.sh
# 			2: job_Ant-v4_POMDP-RN_LSTM-TD3_2.sh
# 			3: job_Ant-v4_POMDP-RN_LSTM-TD3_3.sh
# 	POMDP-RSM
# 		PPO
# 			0: job_Ant-v4_POMDP-RSM_PPO_0.sh
# 			1: job_Ant-v4_POMDP-RSM_PPO_1.sh
# 			2: job_Ant-v4_POMDP-RSM_PPO_2.sh
# 			3: job_Ant-v4_POMDP-RSM_PPO_3.sh
# 		SAC
# 			0: job_Ant-v4_POMDP-RSM_SAC_0.sh
# 			1: job_Ant-v4_POMDP-RSM_SAC_1.sh
# 			2: job_Ant-v4_POMDP-RSM_SAC_2.sh
# 			3: job_Ant-v4_POMDP-RSM_SAC_3.sh
# 		MSAC
# 			0: job_Ant-v4_POMDP-RSM_MSAC_0.sh
# 			1: job_Ant-v4_POMDP-RSM_MSAC_1.sh
# 			2: job_Ant-v4_POMDP-RSM_MSAC_2.sh
# 			3: job_Ant-v4_POMDP-RSM_MSAC_3.sh
# 		TD3
# 			0: job_Ant-v4_POMDP-RSM_TD3_0.sh
# 			1: job_Ant-v4_POMDP-RSM_TD3_1.sh
# 			2: job_Ant-v4_POMDP-RSM_TD3_2.sh
# 			3: job_Ant-v4_POMDP-RSM_TD3_3.sh
# 		MTD3
# 			0: job_Ant-v4_POMDP-RSM_MTD3_0.sh
# 			1: job_Ant-v4_POMDP-RSM_MTD3_1.sh
# 			2: job_Ant-v4_POMDP-RSM_MTD3_2.sh
# 			3: job_Ant-v4_POMDP-RSM_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Ant-v4_POMDP-RSM_LSTM-TD3_0.sh
# 			1: job_Ant-v4_POMDP-RSM_LSTM-TD3_1.sh
# 			2: job_Ant-v4_POMDP-RSM_LSTM-TD3_2.sh
# 			3: job_Ant-v4_POMDP-RSM_LSTM-TD3_3.sh
# Walker2d-v4
# 	MDP
# 		PPO
# 			0: job_Walker2d-v4_MDP_PPO_0.sh
# 			1: job_Walker2d-v4_MDP_PPO_1.sh
# 			2: job_Walker2d-v4_MDP_PPO_2.sh
# 			3: job_Walker2d-v4_MDP_PPO_3.sh
# 		SAC
# 			0: job_Walker2d-v4_MDP_SAC_0.sh
# 			1: job_Walker2d-v4_MDP_SAC_1.sh
# 			2: job_Walker2d-v4_MDP_SAC_2.sh
# 			3: job_Walker2d-v4_MDP_SAC_3.sh
# 		MSAC
# 			0: job_Walker2d-v4_MDP_MSAC_0.sh
# 			1: job_Walker2d-v4_MDP_MSAC_1.sh
# 			2: job_Walker2d-v4_MDP_MSAC_2.sh
# 			3: job_Walker2d-v4_MDP_MSAC_3.sh
# 		TD3
# 			0: job_Walker2d-v4_MDP_TD3_0.sh
# 			1: job_Walker2d-v4_MDP_TD3_1.sh
# 			2: job_Walker2d-v4_MDP_TD3_2.sh
# 			3: job_Walker2d-v4_MDP_TD3_3.sh
# 		MTD3
# 			0: job_Walker2d-v4_MDP_MTD3_0.sh
# 			1: job_Walker2d-v4_MDP_MTD3_1.sh
# 			2: job_Walker2d-v4_MDP_MTD3_2.sh
# 			3: job_Walker2d-v4_MDP_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Walker2d-v4_MDP_LSTM-TD3_0.sh
# 			1: job_Walker2d-v4_MDP_LSTM-TD3_1.sh
# 			2: job_Walker2d-v4_MDP_LSTM-TD3_2.sh
# 			3: job_Walker2d-v4_MDP_LSTM-TD3_3.sh
# 	POMDP-RV
# 		PPO
# 			0: job_Walker2d-v4_POMDP-RV_PPO_0.sh
# 			1: job_Walker2d-v4_POMDP-RV_PPO_1.sh
# 			2: job_Walker2d-v4_POMDP-RV_PPO_2.sh
# 			3: job_Walker2d-v4_POMDP-RV_PPO_3.sh
# 		SAC
# 			0: job_Walker2d-v4_POMDP-RV_SAC_0.sh
# 			1: job_Walker2d-v4_POMDP-RV_SAC_1.sh
# 			2: job_Walker2d-v4_POMDP-RV_SAC_2.sh
# 			3: job_Walker2d-v4_POMDP-RV_SAC_3.sh
# 		MSAC
# 			0: job_Walker2d-v4_POMDP-RV_MSAC_0.sh
# 			1: job_Walker2d-v4_POMDP-RV_MSAC_1.sh
# 			2: job_Walker2d-v4_POMDP-RV_MSAC_2.sh
# 			3: job_Walker2d-v4_POMDP-RV_MSAC_3.sh
# 		TD3
# 			0: job_Walker2d-v4_POMDP-RV_TD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RV_TD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RV_TD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RV_TD3_3.sh
# 		MTD3
# 			0: job_Walker2d-v4_POMDP-RV_MTD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RV_MTD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RV_MTD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RV_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Walker2d-v4_POMDP-RV_LSTM-TD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RV_LSTM-TD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RV_LSTM-TD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RV_LSTM-TD3_3.sh
# 	POMDP-FLK
# 		PPO
# 			0: job_Walker2d-v4_POMDP-FLK_PPO_0.sh
# 			1: job_Walker2d-v4_POMDP-FLK_PPO_1.sh
# 			2: job_Walker2d-v4_POMDP-FLK_PPO_2.sh
# 			3: job_Walker2d-v4_POMDP-FLK_PPO_3.sh
# 		SAC
# 			0: job_Walker2d-v4_POMDP-FLK_SAC_0.sh
# 			1: job_Walker2d-v4_POMDP-FLK_SAC_1.sh
# 			2: job_Walker2d-v4_POMDP-FLK_SAC_2.sh
# 			3: job_Walker2d-v4_POMDP-FLK_SAC_3.sh
# 		MSAC
# 			0: job_Walker2d-v4_POMDP-FLK_MSAC_0.sh
# 			1: job_Walker2d-v4_POMDP-FLK_MSAC_1.sh
# 			2: job_Walker2d-v4_POMDP-FLK_MSAC_2.sh
# 			3: job_Walker2d-v4_POMDP-FLK_MSAC_3.sh
# 		TD3
# 			0: job_Walker2d-v4_POMDP-FLK_TD3_0.sh
# 			1: job_Walker2d-v4_POMDP-FLK_TD3_1.sh
# 			2: job_Walker2d-v4_POMDP-FLK_TD3_2.sh
# 			3: job_Walker2d-v4_POMDP-FLK_TD3_3.sh
# 		MTD3
# 			0: job_Walker2d-v4_POMDP-FLK_MTD3_0.sh
# 			1: job_Walker2d-v4_POMDP-FLK_MTD3_1.sh
# 			2: job_Walker2d-v4_POMDP-FLK_MTD3_2.sh
# 			3: job_Walker2d-v4_POMDP-FLK_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Walker2d-v4_POMDP-FLK_LSTM-TD3_0.sh
# 			1: job_Walker2d-v4_POMDP-FLK_LSTM-TD3_1.sh
# 			2: job_Walker2d-v4_POMDP-FLK_LSTM-TD3_2.sh
# 			3: job_Walker2d-v4_POMDP-FLK_LSTM-TD3_3.sh
# 	POMDP-RN
# 		PPO
# 			0: job_Walker2d-v4_POMDP-RN_PPO_0.sh
# 			1: job_Walker2d-v4_POMDP-RN_PPO_1.sh
# 			2: job_Walker2d-v4_POMDP-RN_PPO_2.sh
# 			3: job_Walker2d-v4_POMDP-RN_PPO_3.sh
# 		SAC
# 			0: job_Walker2d-v4_POMDP-RN_SAC_0.sh
# 			1: job_Walker2d-v4_POMDP-RN_SAC_1.sh
# 			2: job_Walker2d-v4_POMDP-RN_SAC_2.sh
# 			3: job_Walker2d-v4_POMDP-RN_SAC_3.sh
# 		MSAC
# 			0: job_Walker2d-v4_POMDP-RN_MSAC_0.sh
# 			1: job_Walker2d-v4_POMDP-RN_MSAC_1.sh
# 			2: job_Walker2d-v4_POMDP-RN_MSAC_2.sh
# 			3: job_Walker2d-v4_POMDP-RN_MSAC_3.sh
# 		TD3
# 			0: job_Walker2d-v4_POMDP-RN_TD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RN_TD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RN_TD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RN_TD3_3.sh
# 		MTD3
# 			0: job_Walker2d-v4_POMDP-RN_MTD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RN_MTD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RN_MTD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RN_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Walker2d-v4_POMDP-RN_LSTM-TD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RN_LSTM-TD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RN_LSTM-TD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RN_LSTM-TD3_3.sh
# 	POMDP-RSM
# 		PPO
# 			0: job_Walker2d-v4_POMDP-RSM_PPO_0.sh
# 			1: job_Walker2d-v4_POMDP-RSM_PPO_1.sh
# 			2: job_Walker2d-v4_POMDP-RSM_PPO_2.sh
# 			3: job_Walker2d-v4_POMDP-RSM_PPO_3.sh
# 		SAC
# 			0: job_Walker2d-v4_POMDP-RSM_SAC_0.sh
# 			1: job_Walker2d-v4_POMDP-RSM_SAC_1.sh
# 			2: job_Walker2d-v4_POMDP-RSM_SAC_2.sh
# 			3: job_Walker2d-v4_POMDP-RSM_SAC_3.sh
# 		MSAC
# 			0: job_Walker2d-v4_POMDP-RSM_MSAC_0.sh
# 			1: job_Walker2d-v4_POMDP-RSM_MSAC_1.sh
# 			2: job_Walker2d-v4_POMDP-RSM_MSAC_2.sh
# 			3: job_Walker2d-v4_POMDP-RSM_MSAC_3.sh
# 		TD3
# 			0: job_Walker2d-v4_POMDP-RSM_TD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RSM_TD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RSM_TD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RSM_TD3_3.sh
# 		MTD3
# 			0: job_Walker2d-v4_POMDP-RSM_MTD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RSM_MTD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RSM_MTD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RSM_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Walker2d-v4_POMDP-RSM_LSTM-TD3_0.sh
# 			1: job_Walker2d-v4_POMDP-RSM_LSTM-TD3_1.sh
# 			2: job_Walker2d-v4_POMDP-RSM_LSTM-TD3_2.sh
# 			3: job_Walker2d-v4_POMDP-RSM_LSTM-TD3_3.sh
# Hopper-v4
# 	MDP
# 		PPO
# 			0: job_Hopper-v4_MDP_PPO_0.sh
# 			1: job_Hopper-v4_MDP_PPO_1.sh
# 			2: job_Hopper-v4_MDP_PPO_2.sh
# 			3: job_Hopper-v4_MDP_PPO_3.sh
# 		SAC
# 			0: job_Hopper-v4_MDP_SAC_0.sh
# 			1: job_Hopper-v4_MDP_SAC_1.sh
# 			2: job_Hopper-v4_MDP_SAC_2.sh
# 			3: job_Hopper-v4_MDP_SAC_3.sh
# 		MSAC
# 			0: job_Hopper-v4_MDP_MSAC_0.sh
# 			1: job_Hopper-v4_MDP_MSAC_1.sh
# 			2: job_Hopper-v4_MDP_MSAC_2.sh
# 			3: job_Hopper-v4_MDP_MSAC_3.sh
# 		TD3
# 			0: job_Hopper-v4_MDP_TD3_0.sh
# 			1: job_Hopper-v4_MDP_TD3_1.sh
# 			2: job_Hopper-v4_MDP_TD3_2.sh
# 			3: job_Hopper-v4_MDP_TD3_3.sh
# 		MTD3
# 			0: job_Hopper-v4_MDP_MTD3_0.sh
# 			1: job_Hopper-v4_MDP_MTD3_1.sh
# 			2: job_Hopper-v4_MDP_MTD3_2.sh
# 			3: job_Hopper-v4_MDP_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Hopper-v4_MDP_LSTM-TD3_0.sh
# 			1: job_Hopper-v4_MDP_LSTM-TD3_1.sh
# 			2: job_Hopper-v4_MDP_LSTM-TD3_2.sh
# 			3: job_Hopper-v4_MDP_LSTM-TD3_3.sh
# 	POMDP-RV
# 		PPO
# 			0: job_Hopper-v4_POMDP-RV_PPO_0.sh
# 			1: job_Hopper-v4_POMDP-RV_PPO_1.sh
# 			2: job_Hopper-v4_POMDP-RV_PPO_2.sh
# 			3: job_Hopper-v4_POMDP-RV_PPO_3.sh
# 		SAC
# 			0: job_Hopper-v4_POMDP-RV_SAC_0.sh
# 			1: job_Hopper-v4_POMDP-RV_SAC_1.sh
# 			2: job_Hopper-v4_POMDP-RV_SAC_2.sh
# 			3: job_Hopper-v4_POMDP-RV_SAC_3.sh
# 		MSAC
# 			0: job_Hopper-v4_POMDP-RV_MSAC_0.sh
# 			1: job_Hopper-v4_POMDP-RV_MSAC_1.sh
# 			2: job_Hopper-v4_POMDP-RV_MSAC_2.sh
# 			3: job_Hopper-v4_POMDP-RV_MSAC_3.sh
# 		TD3
# 			0: job_Hopper-v4_POMDP-RV_TD3_0.sh
# 			1: job_Hopper-v4_POMDP-RV_TD3_1.sh
# 			2: job_Hopper-v4_POMDP-RV_TD3_2.sh
# 			3: job_Hopper-v4_POMDP-RV_TD3_3.sh
# 		MTD3
# 			0: job_Hopper-v4_POMDP-RV_MTD3_0.sh
# 			1: job_Hopper-v4_POMDP-RV_MTD3_1.sh
# 			2: job_Hopper-v4_POMDP-RV_MTD3_2.sh
# 			3: job_Hopper-v4_POMDP-RV_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Hopper-v4_POMDP-RV_LSTM-TD3_0.sh
# 			1: job_Hopper-v4_POMDP-RV_LSTM-TD3_1.sh
# 			2: job_Hopper-v4_POMDP-RV_LSTM-TD3_2.sh
# 			3: job_Hopper-v4_POMDP-RV_LSTM-TD3_3.sh
# 	POMDP-FLK
# 		PPO
# 			0: job_Hopper-v4_POMDP-FLK_PPO_0.sh
# 			1: job_Hopper-v4_POMDP-FLK_PPO_1.sh
# 			2: job_Hopper-v4_POMDP-FLK_PPO_2.sh
# 			3: job_Hopper-v4_POMDP-FLK_PPO_3.sh
# 		SAC
# 			0: job_Hopper-v4_POMDP-FLK_SAC_0.sh
# 			1: job_Hopper-v4_POMDP-FLK_SAC_1.sh
# 			2: job_Hopper-v4_POMDP-FLK_SAC_2.sh
# 			3: job_Hopper-v4_POMDP-FLK_SAC_3.sh
# 		MSAC
# 			0: job_Hopper-v4_POMDP-FLK_MSAC_0.sh
# 			1: job_Hopper-v4_POMDP-FLK_MSAC_1.sh
# 			2: job_Hopper-v4_POMDP-FLK_MSAC_2.sh
# 			3: job_Hopper-v4_POMDP-FLK_MSAC_3.sh
# 		TD3
# 			0: job_Hopper-v4_POMDP-FLK_TD3_0.sh
# 			1: job_Hopper-v4_POMDP-FLK_TD3_1.sh
# 			2: job_Hopper-v4_POMDP-FLK_TD3_2.sh
# 			3: job_Hopper-v4_POMDP-FLK_TD3_3.sh
# 		MTD3
# 			0: job_Hopper-v4_POMDP-FLK_MTD3_0.sh
# 			1: job_Hopper-v4_POMDP-FLK_MTD3_1.sh
# 			2: job_Hopper-v4_POMDP-FLK_MTD3_2.sh
# 			3: job_Hopper-v4_POMDP-FLK_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Hopper-v4_POMDP-FLK_LSTM-TD3_0.sh
# 			1: job_Hopper-v4_POMDP-FLK_LSTM-TD3_1.sh
# 			2: job_Hopper-v4_POMDP-FLK_LSTM-TD3_2.sh
# 			3: job_Hopper-v4_POMDP-FLK_LSTM-TD3_3.sh
# 	POMDP-RN
# 		PPO
# 			0: job_Hopper-v4_POMDP-RN_PPO_0.sh
# 			1: job_Hopper-v4_POMDP-RN_PPO_1.sh
# 			2: job_Hopper-v4_POMDP-RN_PPO_2.sh
# 			3: job_Hopper-v4_POMDP-RN_PPO_3.sh
# 		SAC
# 			0: job_Hopper-v4_POMDP-RN_SAC_0.sh
# 			1: job_Hopper-v4_POMDP-RN_SAC_1.sh
# 			2: job_Hopper-v4_POMDP-RN_SAC_2.sh
# 			3: job_Hopper-v4_POMDP-RN_SAC_3.sh
# 		MSAC
# 			0: job_Hopper-v4_POMDP-RN_MSAC_0.sh
# 			1: job_Hopper-v4_POMDP-RN_MSAC_1.sh
# 			2: job_Hopper-v4_POMDP-RN_MSAC_2.sh
# 			3: job_Hopper-v4_POMDP-RN_MSAC_3.sh
# 		TD3
# 			0: job_Hopper-v4_POMDP-RN_TD3_0.sh
# 			1: job_Hopper-v4_POMDP-RN_TD3_1.sh
# 			2: job_Hopper-v4_POMDP-RN_TD3_2.sh
# 			3: job_Hopper-v4_POMDP-RN_TD3_3.sh
# 		MTD3
# 			0: job_Hopper-v4_POMDP-RN_MTD3_0.sh
# 			1: job_Hopper-v4_POMDP-RN_MTD3_1.sh
# 			2: job_Hopper-v4_POMDP-RN_MTD3_2.sh
# 			3: job_Hopper-v4_POMDP-RN_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Hopper-v4_POMDP-RN_LSTM-TD3_0.sh
# 			1: job_Hopper-v4_POMDP-RN_LSTM-TD3_1.sh
# 			2: job_Hopper-v4_POMDP-RN_LSTM-TD3_2.sh
# 			3: job_Hopper-v4_POMDP-RN_LSTM-TD3_3.sh
# 	POMDP-RSM
# 		PPO
# 			0: job_Hopper-v4_POMDP-RSM_PPO_0.sh
# 			1: job_Hopper-v4_POMDP-RSM_PPO_1.sh
# 			2: job_Hopper-v4_POMDP-RSM_PPO_2.sh
# 			3: job_Hopper-v4_POMDP-RSM_PPO_3.sh
# 		SAC
# 			0: job_Hopper-v4_POMDP-RSM_SAC_0.sh
# 			1: job_Hopper-v4_POMDP-RSM_SAC_1.sh
# 			2: job_Hopper-v4_POMDP-RSM_SAC_2.sh
# 			3: job_Hopper-v4_POMDP-RSM_SAC_3.sh
# 		MSAC
# 			0: job_Hopper-v4_POMDP-RSM_MSAC_0.sh
# 			1: job_Hopper-v4_POMDP-RSM_MSAC_1.sh
# 			2: job_Hopper-v4_POMDP-RSM_MSAC_2.sh
# 			3: job_Hopper-v4_POMDP-RSM_MSAC_3.sh
# 		TD3
# 			0: job_Hopper-v4_POMDP-RSM_TD3_0.sh
# 			1: job_Hopper-v4_POMDP-RSM_TD3_1.sh
# 			2: job_Hopper-v4_POMDP-RSM_TD3_2.sh
# 			3: job_Hopper-v4_POMDP-RSM_TD3_3.sh
# 		MTD3
# 			0: job_Hopper-v4_POMDP-RSM_MTD3_0.sh
# 			1: job_Hopper-v4_POMDP-RSM_MTD3_1.sh
# 			2: job_Hopper-v4_POMDP-RSM_MTD3_2.sh
# 			3: job_Hopper-v4_POMDP-RSM_MTD3_3.sh
# 		LSTM-TD3
# 			0: job_Hopper-v4_POMDP-RSM_LSTM-TD3_0.sh
# 			1: job_Hopper-v4_POMDP-RSM_LSTM-TD3_1.sh
# 			2: job_Hopper-v4_POMDP-RSM_LSTM-TD3_2.sh
# 			3: job_Hopper-v4_POMDP-RSM_LSTM-TD3_3.sh

# %% [markdown]
# ## Submit job

# %%
job_script_list = os.listdir(job_dir)
job_script_list.sort()
job_script_list
# Out:
# ['MUJOCO_LOG.TXT',
#  'job_Ant-v4_MDP_LSTM-TD3_0.sh',
#  'job_Ant-v4_MDP_LSTM-TD3_1.sh',
#  'job_Ant-v4_MDP_LSTM-TD3_2.sh',
#  'job_Ant-v4_MDP_LSTM-TD3_3.sh',
#  'job_Ant-v4_MDP_MSAC_0.sh',
#  'job_Ant-v4_MDP_MSAC_1.sh',
#  'job_Ant-v4_MDP_MSAC_2.sh',
#  'job_Ant-v4_MDP_MSAC_3.sh',
#  'job_Ant-v4_MDP_MTD3_0.sh',
#  'job_Ant-v4_MDP_MTD3_1.sh',
#  'job_Ant-v4_MDP_MTD3_2.sh',
#  'job_Ant-v4_MDP_MTD3_3.sh',
#  'job_Ant-v4_MDP_PPO_0.sh',
#  'job_Ant-v4_MDP_PPO_1.sh',
#  'job_Ant-v4_MDP_PPO_2.sh',
#  'job_Ant-v4_MDP_PPO_3.sh',
#  'job_Ant-v4_MDP_SAC_0.sh',
#  'job_Ant-v4_MDP_SAC_1.sh',
#  'job_Ant-v4_MDP_SAC_2.sh',
#  'job_Ant-v4_MDP_SAC_3.sh',
#  'job_Ant-v4_MDP_TD3_0.sh',
#  'job_Ant-v4_MDP_TD3_1.sh',
#  'job_Ant-v4_MDP_TD3_2.sh',
#  'job_Ant-v4_MDP_TD3_3.sh',
#  'job_Ant-v4_POMDP-FLK_LSTM-TD3_0.sh',
#  'job_Ant-v4_POMDP-FLK_LSTM-TD3_1.sh',
#  'job_Ant-v4_POMDP-FLK_LSTM-TD3_2.sh',
#  'job_Ant-v4_POMDP-FLK_LSTM-TD3_3.sh',
#  'job_Ant-v4_POMDP-FLK_MSAC_0.sh',
#  'job_Ant-v4_POMDP-FLK_MSAC_1.sh',
#  'job_Ant-v4_POMDP-FLK_MSAC_2.sh',
#  'job_Ant-v4_POMDP-FLK_MSAC_3.sh',
#  'job_Ant-v4_POMDP-FLK_MTD3_0.sh',
#  'job_Ant-v4_POMDP-FLK_MTD3_1.sh',
#  'job_Ant-v4_POMDP-FLK_MTD3_2.sh',
#  'job_Ant-v4_POMDP-FLK_MTD3_3.sh',
#  'job_Ant-v4_POMDP-FLK_PPO_0.sh',
#  'job_Ant-v4_POMDP-FLK_PPO_1.sh',
#  'job_Ant-v4_POMDP-FLK_PPO_2.sh',
#  'job_Ant-v4_POMDP-FLK_PPO_3.sh',
#  'job_Ant-v4_POMDP-FLK_SAC_0.sh',
#  'job_Ant-v4_POMDP-FLK_SAC_1.sh',
#  'job_Ant-v4_POMDP-FLK_SAC_2.sh',
#  'job_Ant-v4_POMDP-FLK_SAC_3.sh',
#  'job_Ant-v4_POMDP-FLK_TD3_0.sh',
#  'job_Ant-v4_POMDP-FLK_TD3_1.sh',
#  'job_Ant-v4_POMDP-FLK_TD3_2.sh',
#  'job_Ant-v4_POMDP-FLK_TD3_3.sh',
#  'job_Ant-v4_POMDP-RN_LSTM-TD3_0.sh',
#  'job_Ant-v4_POMDP-RN_LSTM-TD3_1.sh',
#  'job_Ant-v4_POMDP-RN_LSTM-TD3_2.sh',
#  'job_Ant-v4_POMDP-RN_LSTM-TD3_3.sh',
#  'job_Ant-v4_POMDP-RN_MSAC_0.sh',
#  'job_Ant-v4_POMDP-RN_MSAC_1.sh',
#  'job_Ant-v4_POMDP-RN_MSAC_2.sh',
#  'job_Ant-v4_POMDP-RN_MSAC_3.sh',
#  'job_Ant-v4_POMDP-RN_MTD3_0.sh',
#  'job_Ant-v4_POMDP-RN_MTD3_1.sh',
#  'job_Ant-v4_POMDP-RN_MTD3_2.sh',
#  'job_Ant-v4_POMDP-RN_MTD3_3.sh',
#  'job_Ant-v4_POMDP-RN_PPO_0.sh',
#  'job_Ant-v4_POMDP-RN_PPO_1.sh',
#  'job_Ant-v4_POMDP-RN_PPO_2.sh',
#  'job_Ant-v4_POMDP-RN_PPO_3.sh',
#  'job_Ant-v4_POMDP-RN_SAC_0.sh',
#  'job_Ant-v4_POMDP-RN_SAC_1.sh',
#  'job_Ant-v4_POMDP-RN_SAC_2.sh',
#  'job_Ant-v4_POMDP-RN_SAC_3.sh',
#  'job_Ant-v4_POMDP-RN_TD3_0.sh',
#  'job_Ant-v4_POMDP-RN_TD3_1.sh',
#  'job_Ant-v4_POMDP-RN_TD3_2.sh',
#  'job_Ant-v4_POMDP-RN_TD3_3.sh',
#  'job_Ant-v4_POMDP-RSM_LSTM-TD3_0.sh',
#  'job_Ant-v4_POMDP-RSM_LSTM-TD3_1.sh',
#  'job_Ant-v4_POMDP-RSM_LSTM-TD3_2.sh',
#  'job_Ant-v4_POMDP-RSM_LSTM-TD3_3.sh',
#  'job_Ant-v4_POMDP-RSM_MSAC_0.sh',
#  'job_Ant-v4_POMDP-RSM_MSAC_1.sh',
#  'job_Ant-v4_POMDP-RSM_MSAC_2.sh',
#  'job_Ant-v4_POMDP-RSM_MSAC_3.sh',
#  'job_Ant-v4_POMDP-RSM_MTD3_0.sh',
#  'job_Ant-v4_POMDP-RSM_MTD3_1.sh',
#  'job_Ant-v4_POMDP-RSM_MTD3_2.sh',
#  'job_Ant-v4_POMDP-RSM_MTD3_3.sh',
#  'job_Ant-v4_POMDP-RSM_PPO_0.sh',
#  'job_Ant-v4_POMDP-RSM_PPO_1.sh',
#  'job_Ant-v4_POMDP-RSM_PPO_2.sh',
#  'job_Ant-v4_POMDP-RSM_PPO_3.sh',
#  'job_Ant-v4_POMDP-RSM_SAC_0.sh',
#  'job_Ant-v4_POMDP-RSM_SAC_1.sh',
#  'job_Ant-v4_POMDP-RSM_SAC_2.sh',
#  'job_Ant-v4_POMDP-RSM_SAC_3.sh',
#  'job_Ant-v4_POMDP-RSM_TD3_0.sh',
#  'job_Ant-v4_POMDP-RSM_TD3_1.sh',
#  'job_Ant-v4_POMDP-RSM_TD3_2.sh',
#  'job_Ant-v4_POMDP-RSM_TD3_3.sh',
#  'job_Ant-v4_POMDP-RV_LSTM-TD3_0.sh',
#  'job_Ant-v4_POMDP-RV_LSTM-TD3_1.sh',
#  'job_Ant-v4_POMDP-RV_LSTM-TD3_2.sh',
#  'job_Ant-v4_POMDP-RV_LSTM-TD3_3.sh',
#  'job_Ant-v4_POMDP-RV_MSAC_0.sh',
#  'job_Ant-v4_POMDP-RV_MSAC_1.sh',
#  'job_Ant-v4_POMDP-RV_MSAC_2.sh',
#  'job_Ant-v4_POMDP-RV_MSAC_3.sh',
#  'job_Ant-v4_POMDP-RV_MTD3_0.sh',
#  'job_Ant-v4_POMDP-RV_MTD3_1.sh',
#  'job_Ant-v4_POMDP-RV_MTD3_2.sh',
#  'job_Ant-v4_POMDP-RV_MTD3_3.sh',
#  'job_Ant-v4_POMDP-RV_PPO_0.sh',
#  'job_Ant-v4_POMDP-RV_PPO_1.sh',
#  'job_Ant-v4_POMDP-RV_PPO_2.sh',
#  'job_Ant-v4_POMDP-RV_PPO_3.sh',
#  'job_Ant-v4_POMDP-RV_SAC_0.sh',
#  'job_Ant-v4_POMDP-RV_SAC_1.sh',
#  'job_Ant-v4_POMDP-RV_SAC_2.sh',
#  'job_Ant-v4_POMDP-RV_SAC_3.sh',
#  'job_Ant-v4_POMDP-RV_TD3_0.sh',
#  'job_Ant-v4_POMDP-RV_TD3_1.sh',
#  'job_Ant-v4_POMDP-RV_TD3_2.sh',
#  'job_Ant-v4_POMDP-RV_TD3_3.sh',
#  'job_HalfCheetah-v4_MDP_LSTM-TD3_0.sh',
#  'job_HalfCheetah-v4_MDP_LSTM-TD3_1.sh',
#  'job_HalfCheetah-v4_MDP_LSTM-TD3_2.sh',
#  'job_HalfCheetah-v4_MDP_LSTM-TD3_3.sh',
#  'job_HalfCheetah-v4_MDP_MSAC_0.sh',
#  'job_HalfCheetah-v4_MDP_MSAC_1.sh',
#  'job_HalfCheetah-v4_MDP_MSAC_2.sh',
#  'job_HalfCheetah-v4_MDP_MSAC_3.sh',
#  'job_HalfCheetah-v4_MDP_MTD3_0.sh',
#  'job_HalfCheetah-v4_MDP_MTD3_1.sh',
#  'job_HalfCheetah-v4_MDP_MTD3_2.sh',
#  'job_HalfCheetah-v4_MDP_MTD3_3.sh',
#  'job_HalfCheetah-v4_MDP_PPO_0.sh',
#  'job_HalfCheetah-v4_MDP_PPO_1.sh',
#  'job_HalfCheetah-v4_MDP_PPO_2.sh',
#  'job_HalfCheetah-v4_MDP_PPO_3.sh',
#  'job_HalfCheetah-v4_MDP_SAC_0.sh',
#  'job_HalfCheetah-v4_MDP_SAC_1.sh',
#  'job_HalfCheetah-v4_MDP_SAC_2.sh',
#  'job_HalfCheetah-v4_MDP_SAC_3.sh',
#  'job_HalfCheetah-v4_MDP_TD3_0.sh',
#  'job_HalfCheetah-v4_MDP_TD3_1.sh',
#  'job_HalfCheetah-v4_MDP_TD3_2.sh',
#  'job_HalfCheetah-v4_MDP_TD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_MSAC_0.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_MSAC_1.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_MSAC_2.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_MSAC_3.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_MTD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_MTD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_MTD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_MTD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_PPO_0.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_PPO_1.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_PPO_2.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_PPO_3.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_SAC_0.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_SAC_1.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_SAC_2.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_SAC_3.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_TD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_TD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_TD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-FLK_TD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RN_LSTM-TD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RN_LSTM-TD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RN_LSTM-TD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RN_LSTM-TD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RN_MSAC_0.sh',
#  'job_HalfCheetah-v4_POMDP-RN_MSAC_1.sh',
#  'job_HalfCheetah-v4_POMDP-RN_MSAC_2.sh',
#  'job_HalfCheetah-v4_POMDP-RN_MSAC_3.sh',
#  'job_HalfCheetah-v4_POMDP-RN_MTD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RN_MTD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RN_MTD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RN_MTD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RN_PPO_0.sh',
#  'job_HalfCheetah-v4_POMDP-RN_PPO_1.sh',
#  'job_HalfCheetah-v4_POMDP-RN_PPO_2.sh',
#  'job_HalfCheetah-v4_POMDP-RN_PPO_3.sh',
#  'job_HalfCheetah-v4_POMDP-RN_SAC_0.sh',
#  'job_HalfCheetah-v4_POMDP-RN_SAC_1.sh',
#  'job_HalfCheetah-v4_POMDP-RN_SAC_2.sh',
#  'job_HalfCheetah-v4_POMDP-RN_SAC_3.sh',
#  'job_HalfCheetah-v4_POMDP-RN_TD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RN_TD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RN_TD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RN_TD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_MSAC_0.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_MSAC_1.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_MSAC_2.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_MSAC_3.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_MTD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_MTD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_MTD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_MTD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_PPO_0.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_PPO_1.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_PPO_2.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_PPO_3.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_SAC_0.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_SAC_1.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_SAC_2.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_SAC_3.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_TD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_TD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_TD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RSM_TD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RV_LSTM-TD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RV_LSTM-TD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RV_LSTM-TD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RV_LSTM-TD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RV_MSAC_0.sh',
#  'job_HalfCheetah-v4_POMDP-RV_MSAC_1.sh',
#  'job_HalfCheetah-v4_POMDP-RV_MSAC_2.sh',
#  'job_HalfCheetah-v4_POMDP-RV_MSAC_3.sh',
#  'job_HalfCheetah-v4_POMDP-RV_MTD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RV_MTD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RV_MTD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RV_MTD3_3.sh',
#  'job_HalfCheetah-v4_POMDP-RV_PPO_0.sh',
#  'job_HalfCheetah-v4_POMDP-RV_PPO_1.sh',
#  'job_HalfCheetah-v4_POMDP-RV_PPO_2.sh',
#  'job_HalfCheetah-v4_POMDP-RV_PPO_3.sh',
#  'job_HalfCheetah-v4_POMDP-RV_SAC_0.sh',
#  'job_HalfCheetah-v4_POMDP-RV_SAC_1.sh',
#  'job_HalfCheetah-v4_POMDP-RV_SAC_2.sh',
#  'job_HalfCheetah-v4_POMDP-RV_SAC_3.sh',
#  'job_HalfCheetah-v4_POMDP-RV_TD3_0.sh',
#  'job_HalfCheetah-v4_POMDP-RV_TD3_1.sh',
#  'job_HalfCheetah-v4_POMDP-RV_TD3_2.sh',
#  'job_HalfCheetah-v4_POMDP-RV_TD3_3.sh',
#  'job_Hopper-v4_MDP_LSTM-TD3_0.sh',
#  'job_Hopper-v4_MDP_LSTM-TD3_1.sh',
#  'job_Hopper-v4_MDP_LSTM-TD3_2.sh',
#  'job_Hopper-v4_MDP_LSTM-TD3_3.sh',
#  'job_Hopper-v4_MDP_MSAC_0.sh',
#  'job_Hopper-v4_MDP_MSAC_1.sh',
#  'job_Hopper-v4_MDP_MSAC_2.sh',
#  'job_Hopper-v4_MDP_MSAC_3.sh',
#  'job_Hopper-v4_MDP_MTD3_0.sh',
#  'job_Hopper-v4_MDP_MTD3_1.sh',
#  'job_Hopper-v4_MDP_MTD3_2.sh',
#  'job_Hopper-v4_MDP_MTD3_3.sh',
#  'job_Hopper-v4_MDP_PPO_0.sh',
#  'job_Hopper-v4_MDP_PPO_1.sh',
#  'job_Hopper-v4_MDP_PPO_2.sh',
#  'job_Hopper-v4_MDP_PPO_3.sh',
#  'job_Hopper-v4_MDP_SAC_0.sh',
#  'job_Hopper-v4_MDP_SAC_1.sh',
#  'job_Hopper-v4_MDP_SAC_2.sh',
#  'job_Hopper-v4_MDP_SAC_3.sh',
#  'job_Hopper-v4_MDP_TD3_0.sh',
#  'job_Hopper-v4_MDP_TD3_1.sh',
#  'job_Hopper-v4_MDP_TD3_2.sh',
#  'job_Hopper-v4_MDP_TD3_3.sh',
#  'job_Hopper-v4_POMDP-FLK_LSTM-TD3_0.sh',
#  'job_Hopper-v4_POMDP-FLK_LSTM-TD3_1.sh',
#  'job_Hopper-v4_POMDP-FLK_LSTM-TD3_2.sh',
#  'job_Hopper-v4_POMDP-FLK_LSTM-TD3_3.sh',
#  'job_Hopper-v4_POMDP-FLK_MSAC_0.sh',
#  'job_Hopper-v4_POMDP-FLK_MSAC_1.sh',
#  'job_Hopper-v4_POMDP-FLK_MSAC_2.sh',
#  'job_Hopper-v4_POMDP-FLK_MSAC_3.sh',
#  'job_Hopper-v4_POMDP-FLK_MTD3_0.sh',
#  'job_Hopper-v4_POMDP-FLK_MTD3_1.sh',
#  'job_Hopper-v4_POMDP-FLK_MTD3_2.sh',
#  'job_Hopper-v4_POMDP-FLK_MTD3_3.sh',
#  'job_Hopper-v4_POMDP-FLK_PPO_0.sh',
#  'job_Hopper-v4_POMDP-FLK_PPO_1.sh',
#  'job_Hopper-v4_POMDP-FLK_PPO_2.sh',
#  'job_Hopper-v4_POMDP-FLK_PPO_3.sh',
#  'job_Hopper-v4_POMDP-FLK_SAC_0.sh',
#  'job_Hopper-v4_POMDP-FLK_SAC_1.sh',
#  'job_Hopper-v4_POMDP-FLK_SAC_2.sh',
#  'job_Hopper-v4_POMDP-FLK_SAC_3.sh',
#  'job_Hopper-v4_POMDP-FLK_TD3_0.sh',
#  'job_Hopper-v4_POMDP-FLK_TD3_1.sh',
#  'job_Hopper-v4_POMDP-FLK_TD3_2.sh',
#  'job_Hopper-v4_POMDP-FLK_TD3_3.sh',
#  'job_Hopper-v4_POMDP-RN_LSTM-TD3_0.sh',
#  'job_Hopper-v4_POMDP-RN_LSTM-TD3_1.sh',
#  'job_Hopper-v4_POMDP-RN_LSTM-TD3_2.sh',
#  'job_Hopper-v4_POMDP-RN_LSTM-TD3_3.sh',
#  'job_Hopper-v4_POMDP-RN_MSAC_0.sh',
#  'job_Hopper-v4_POMDP-RN_MSAC_1.sh',
#  'job_Hopper-v4_POMDP-RN_MSAC_2.sh',
#  'job_Hopper-v4_POMDP-RN_MSAC_3.sh',
#  'job_Hopper-v4_POMDP-RN_MTD3_0.sh',
#  'job_Hopper-v4_POMDP-RN_MTD3_1.sh',
#  'job_Hopper-v4_POMDP-RN_MTD3_2.sh',
#  'job_Hopper-v4_POMDP-RN_MTD3_3.sh',
#  'job_Hopper-v4_POMDP-RN_PPO_0.sh',
#  'job_Hopper-v4_POMDP-RN_PPO_1.sh',
#  'job_Hopper-v4_POMDP-RN_PPO_2.sh',
#  'job_Hopper-v4_POMDP-RN_PPO_3.sh',
#  'job_Hopper-v4_POMDP-RN_SAC_0.sh',
#  'job_Hopper-v4_POMDP-RN_SAC_1.sh',
#  'job_Hopper-v4_POMDP-RN_SAC_2.sh',
#  'job_Hopper-v4_POMDP-RN_SAC_3.sh',
#  'job_Hopper-v4_POMDP-RN_TD3_0.sh',
#  'job_Hopper-v4_POMDP-RN_TD3_1.sh',
#  'job_Hopper-v4_POMDP-RN_TD3_2.sh',
#  'job_Hopper-v4_POMDP-RN_TD3_3.sh',
#  'job_Hopper-v4_POMDP-RSM_LSTM-TD3_0.sh',
#  'job_Hopper-v4_POMDP-RSM_LSTM-TD3_1.sh',
#  'job_Hopper-v4_POMDP-RSM_LSTM-TD3_2.sh',
#  'job_Hopper-v4_POMDP-RSM_LSTM-TD3_3.sh',
#  'job_Hopper-v4_POMDP-RSM_MSAC_0.sh',
#  'job_Hopper-v4_POMDP-RSM_MSAC_1.sh',
#  'job_Hopper-v4_POMDP-RSM_MSAC_2.sh',
#  'job_Hopper-v4_POMDP-RSM_MSAC_3.sh',
#  'job_Hopper-v4_POMDP-RSM_MTD3_0.sh',
#  'job_Hopper-v4_POMDP-RSM_MTD3_1.sh',
#  'job_Hopper-v4_POMDP-RSM_MTD3_2.sh',
#  'job_Hopper-v4_POMDP-RSM_MTD3_3.sh',
#  'job_Hopper-v4_POMDP-RSM_PPO_0.sh',
#  'job_Hopper-v4_POMDP-RSM_PPO_1.sh',
#  'job_Hopper-v4_POMDP-RSM_PPO_2.sh',
#  'job_Hopper-v4_POMDP-RSM_PPO_3.sh',
#  'job_Hopper-v4_POMDP-RSM_SAC_0.sh',
#  'job_Hopper-v4_POMDP-RSM_SAC_1.sh',
#  'job_Hopper-v4_POMDP-RSM_SAC_2.sh',
#  'job_Hopper-v4_POMDP-RSM_SAC_3.sh',
#  'job_Hopper-v4_POMDP-RSM_TD3_0.sh',
#  'job_Hopper-v4_POMDP-RSM_TD3_1.sh',
#  'job_Hopper-v4_POMDP-RSM_TD3_2.sh',
#  'job_Hopper-v4_POMDP-RSM_TD3_3.sh',
#  'job_Hopper-v4_POMDP-RV_LSTM-TD3_0.sh',
#  'job_Hopper-v4_POMDP-RV_LSTM-TD3_1.sh',
#  'job_Hopper-v4_POMDP-RV_LSTM-TD3_2.sh',
#  'job_Hopper-v4_POMDP-RV_LSTM-TD3_3.sh',
#  'job_Hopper-v4_POMDP-RV_MSAC_0.sh',
#  'job_Hopper-v4_POMDP-RV_MSAC_1.sh',
#  'job_Hopper-v4_POMDP-RV_MSAC_2.sh',
#  'job_Hopper-v4_POMDP-RV_MSAC_3.sh',
#  'job_Hopper-v4_POMDP-RV_MTD3_0.sh',
#  'job_Hopper-v4_POMDP-RV_MTD3_1.sh',
#  'job_Hopper-v4_POMDP-RV_MTD3_2.sh',
#  'job_Hopper-v4_POMDP-RV_MTD3_3.sh',
#  'job_Hopper-v4_POMDP-RV_PPO_0.sh',
#  'job_Hopper-v4_POMDP-RV_PPO_1.sh',
#  'job_Hopper-v4_POMDP-RV_PPO_2.sh',
#  'job_Hopper-v4_POMDP-RV_PPO_3.sh',
#  'job_Hopper-v4_POMDP-RV_SAC_0.sh',
#  'job_Hopper-v4_POMDP-RV_SAC_1.sh',
#  'job_Hopper-v4_POMDP-RV_SAC_2.sh',
#  'job_Hopper-v4_POMDP-RV_SAC_3.sh',
#  'job_Hopper-v4_POMDP-RV_TD3_0.sh',
#  'job_Hopper-v4_POMDP-RV_TD3_1.sh',
#  'job_Hopper-v4_POMDP-RV_TD3_2.sh',
#  'job_Hopper-v4_POMDP-RV_TD3_3.sh',
#  'job_Walker2d-v4_MDP_LSTM-TD3_0.sh',
#  'job_Walker2d-v4_MDP_LSTM-TD3_1.sh',
#  'job_Walker2d-v4_MDP_LSTM-TD3_2.sh',
#  'job_Walker2d-v4_MDP_LSTM-TD3_3.sh',
#  'job_Walker2d-v4_MDP_MSAC_0.sh',
#  'job_Walker2d-v4_MDP_MSAC_1.sh',
#  'job_Walker2d-v4_MDP_MSAC_2.sh',
#  'job_Walker2d-v4_MDP_MSAC_3.sh',
#  'job_Walker2d-v4_MDP_MTD3_0.sh',
#  'job_Walker2d-v4_MDP_MTD3_1.sh',
#  'job_Walker2d-v4_MDP_MTD3_2.sh',
#  'job_Walker2d-v4_MDP_MTD3_3.sh',
#  'job_Walker2d-v4_MDP_PPO_0.sh',
#  'job_Walker2d-v4_MDP_PPO_1.sh',
#  'job_Walker2d-v4_MDP_PPO_2.sh',
#  'job_Walker2d-v4_MDP_PPO_3.sh',
#  'job_Walker2d-v4_MDP_SAC_0.sh',
#  'job_Walker2d-v4_MDP_SAC_1.sh',
#  'job_Walker2d-v4_MDP_SAC_2.sh',
#  'job_Walker2d-v4_MDP_SAC_3.sh',
#  'job_Walker2d-v4_MDP_TD3_0.sh',
#  'job_Walker2d-v4_MDP_TD3_1.sh',
#  'job_Walker2d-v4_MDP_TD3_2.sh',
#  'job_Walker2d-v4_MDP_TD3_3.sh',
#  'job_Walker2d-v4_POMDP-FLK_LSTM-TD3_0.sh',
#  'job_Walker2d-v4_POMDP-FLK_LSTM-TD3_1.sh',
#  'job_Walker2d-v4_POMDP-FLK_LSTM-TD3_2.sh',
#  'job_Walker2d-v4_POMDP-FLK_LSTM-TD3_3.sh',
#  'job_Walker2d-v4_POMDP-FLK_MSAC_0.sh',
#  'job_Walker2d-v4_POMDP-FLK_MSAC_1.sh',
#  'job_Walker2d-v4_POMDP-FLK_MSAC_2.sh',
#  'job_Walker2d-v4_POMDP-FLK_MSAC_3.sh',
#  'job_Walker2d-v4_POMDP-FLK_MTD3_0.sh',
#  'job_Walker2d-v4_POMDP-FLK_MTD3_1.sh',
#  'job_Walker2d-v4_POMDP-FLK_MTD3_2.sh',
#  'job_Walker2d-v4_POMDP-FLK_MTD3_3.sh',
#  'job_Walker2d-v4_POMDP-FLK_PPO_0.sh',
#  'job_Walker2d-v4_POMDP-FLK_PPO_1.sh',
#  'job_Walker2d-v4_POMDP-FLK_PPO_2.sh',
#  'job_Walker2d-v4_POMDP-FLK_PPO_3.sh',
#  'job_Walker2d-v4_POMDP-FLK_SAC_0.sh',
#  'job_Walker2d-v4_POMDP-FLK_SAC_1.sh',
#  'job_Walker2d-v4_POMDP-FLK_SAC_2.sh',
#  'job_Walker2d-v4_POMDP-FLK_SAC_3.sh',
#  'job_Walker2d-v4_POMDP-FLK_TD3_0.sh',
#  'job_Walker2d-v4_POMDP-FLK_TD3_1.sh',
#  'job_Walker2d-v4_POMDP-FLK_TD3_2.sh',
#  'job_Walker2d-v4_POMDP-FLK_TD3_3.sh',
#  'job_Walker2d-v4_POMDP-RN_LSTM-TD3_0.sh',
#  'job_Walker2d-v4_POMDP-RN_LSTM-TD3_1.sh',
#  'job_Walker2d-v4_POMDP-RN_LSTM-TD3_2.sh',
#  'job_Walker2d-v4_POMDP-RN_LSTM-TD3_3.sh',
#  'job_Walker2d-v4_POMDP-RN_MSAC_0.sh',
#  'job_Walker2d-v4_POMDP-RN_MSAC_1.sh',
#  'job_Walker2d-v4_POMDP-RN_MSAC_2.sh',
#  'job_Walker2d-v4_POMDP-RN_MSAC_3.sh',
#  'job_Walker2d-v4_POMDP-RN_MTD3_0.sh',
#  'job_Walker2d-v4_POMDP-RN_MTD3_1.sh',
#  'job_Walker2d-v4_POMDP-RN_MTD3_2.sh',
#  'job_Walker2d-v4_POMDP-RN_MTD3_3.sh',
#  'job_Walker2d-v4_POMDP-RN_PPO_0.sh',
#  'job_Walker2d-v4_POMDP-RN_PPO_1.sh',
#  'job_Walker2d-v4_POMDP-RN_PPO_2.sh',
#  'job_Walker2d-v4_POMDP-RN_PPO_3.sh',
#  'job_Walker2d-v4_POMDP-RN_SAC_0.sh',
#  'job_Walker2d-v4_POMDP-RN_SAC_1.sh',
#  'job_Walker2d-v4_POMDP-RN_SAC_2.sh',
#  'job_Walker2d-v4_POMDP-RN_SAC_3.sh',
#  'job_Walker2d-v4_POMDP-RN_TD3_0.sh',
#  'job_Walker2d-v4_POMDP-RN_TD3_1.sh',
#  'job_Walker2d-v4_POMDP-RN_TD3_2.sh',
#  'job_Walker2d-v4_POMDP-RN_TD3_3.sh',
#  'job_Walker2d-v4_POMDP-RSM_LSTM-TD3_0.sh',
#  'job_Walker2d-v4_POMDP-RSM_LSTM-TD3_1.sh',
#  'job_Walker2d-v4_POMDP-RSM_LSTM-TD3_2.sh',
#  'job_Walker2d-v4_POMDP-RSM_LSTM-TD3_3.sh',
#  'job_Walker2d-v4_POMDP-RSM_MSAC_0.sh',
#  'job_Walker2d-v4_POMDP-RSM_MSAC_1.sh',
#  'job_Walker2d-v4_POMDP-RSM_MSAC_2.sh',
#  'job_Walker2d-v4_POMDP-RSM_MSAC_3.sh',
#  'job_Walker2d-v4_POMDP-RSM_MTD3_0.sh',
#  'job_Walker2d-v4_POMDP-RSM_MTD3_1.sh',
#  'job_Walker2d-v4_POMDP-RSM_MTD3_2.sh',
#  'job_Walker2d-v4_POMDP-RSM_MTD3_3.sh',
#  'job_Walker2d-v4_POMDP-RSM_PPO_0.sh',
#  'job_Walker2d-v4_POMDP-RSM_PPO_1.sh',
#  'job_Walker2d-v4_POMDP-RSM_PPO_2.sh',
#  'job_Walker2d-v4_POMDP-RSM_PPO_3.sh',
#  'job_Walker2d-v4_POMDP-RSM_SAC_0.sh',
#  'job_Walker2d-v4_POMDP-RSM_SAC_1.sh',
#  'job_Walker2d-v4_POMDP-RSM_SAC_2.sh',
#  'job_Walker2d-v4_POMDP-RSM_SAC_3.sh',
#  'job_Walker2d-v4_POMDP-RSM_TD3_0.sh',
#  'job_Walker2d-v4_POMDP-RSM_TD3_1.sh',
#  'job_Walker2d-v4_POMDP-RSM_TD3_2.sh',
#  'job_Walker2d-v4_POMDP-RSM_TD3_3.sh',
#  'job_Walker2d-v4_POMDP-RV_LSTM-TD3_0.sh',
#  'job_Walker2d-v4_POMDP-RV_LSTM-TD3_1.sh',
#  'job_Walker2d-v4_POMDP-RV_LSTM-TD3_2.sh',
#  'job_Walker2d-v4_POMDP-RV_LSTM-TD3_3.sh',
#  'job_Walker2d-v4_POMDP-RV_MSAC_0.sh',
#  'job_Walker2d-v4_POMDP-RV_MSAC_1.sh',
#  'job_Walker2d-v4_POMDP-RV_MSAC_2.sh',
#  'job_Walker2d-v4_POMDP-RV_MSAC_3.sh',
#  'job_Walker2d-v4_POMDP-RV_MTD3_0.sh',
#  'job_Walker2d-v4_POMDP-RV_MTD3_1.sh',
#  'job_Walker2d-v4_POMDP-RV_MTD3_2.sh',
#  'job_Walker2d-v4_POMDP-RV_MTD3_3.sh',
#  'job_Walker2d-v4_POMDP-RV_PPO_0.sh',
#  'job_Walker2d-v4_POMDP-RV_PPO_1.sh',
#  'job_Walker2d-v4_POMDP-RV_PPO_2.sh',
#  'job_Walker2d-v4_POMDP-RV_PPO_3.sh',
#  'job_Walker2d-v4_POMDP-RV_SAC_0.sh',
#  'job_Walker2d-v4_POMDP-RV_SAC_1.sh',
#  'job_Walker2d-v4_POMDP-RV_SAC_2.sh',
#  'job_Walker2d-v4_POMDP-RV_SAC_3.sh',
#  'job_Walker2d-v4_POMDP-RV_TD3_0.sh',
#  'job_Walker2d-v4_POMDP-RV_TD3_1.sh',
#  'job_Walker2d-v4_POMDP-RV_TD3_2.sh',
#  'job_Walker2d-v4_POMDP-RV_TD3_3.sh']

# %%
len(job_script_list)
# Out:
# 481

# %%
for job_i, job_script in enumerate(job_script_list):
    if '.sh' not in job_script:
        continue
    if 'PPO' not in job_script:
        continue
    job_script_path = os.path.join(job_dir, job_script)
    print('Submitting {}: {}'.format(job_i, job_script_path))
    # !sbatch {job_script_path} 
    print("#########################################################################################")
# Out:
# Submitting 13: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_MDP_PPO_0.sh
# Submitted batch job 40234774
# #########################################################################################
# Submitting 14: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_MDP_PPO_1.sh
# Submitted batch job 40234775
# #########################################################################################
# Submitting 15: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_MDP_PPO_2.sh
# Submitted batch job 40234776
# #########################################################################################
# Submitting 16: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_MDP_PPO_3.sh
# Submitted batch job 40234777
# #########################################################################################
# Submitting 37: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-FLK_PPO_0.sh
# Submitted batch job 40234778
# #########################################################################################
# Submitting 38: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-FLK_PPO_1.sh
# Submitted batch job 40234779
# #########################################################################################
# Submitting 39: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-FLK_PPO_2.sh
# Submitted batch job 40234780
# #########################################################################################
# Submitting 40: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-FLK_PPO_3.sh
# Submitted batch job 40234781
# #########################################################################################
# Submitting 61: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RN_PPO_0.sh
# Submitted batch job 40234782
# #########################################################################################
# Submitting 62: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RN_PPO_1.sh
# Submitted batch job 40234783
# #########################################################################################
# Submitting 63: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RN_PPO_2.sh
# Submitted batch job 40234784
# #########################################################################################
# Submitting 64: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RN_PPO_3.sh
# Submitted batch job 40234785
# #########################################################################################
# Submitting 85: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RSM_PPO_0.sh
# Submitted batch job 40234786
# #########################################################################################
# Submitting 86: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RSM_PPO_1.sh
# Submitted batch job 40234787
# #########################################################################################
# Submitting 87: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RSM_PPO_2.sh
# Submitted batch job 40234788
# #########################################################################################
# Submitting 88: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RSM_PPO_3.sh
# Submitted batch job 40234789
# #########################################################################################
# Submitting 109: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RV_PPO_0.sh
# Submitted batch job 40234790
# #########################################################################################
# Submitting 110: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RV_PPO_1.sh
# Submitted batch job 40234791
# #########################################################################################
# Submitting 111: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RV_PPO_2.sh
# Submitted batch job 40234792
# #########################################################################################
# Submitting 112: /scratch/lingheng/mrl_job_scripts/job_Ant-v4_POMDP-RV_PPO_3.sh
# Submitted batch job 40234793
# #########################################################################################
# Submitting 133: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_MDP_PPO_0.sh
# Submitted batch job 40234794
# #########################################################################################
# Submitting 134: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_MDP_PPO_1.sh
# Submitted batch job 40234795
# #########################################################################################
# Submitting 135: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_MDP_PPO_2.sh
# Submitted batch job 40234796
# #########################################################################################
# Submitting 136: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_MDP_PPO_3.sh
# Submitted batch job 40234797
# #########################################################################################
# Submitting 157: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-FLK_PPO_0.sh
# Submitted batch job 40234798
# #########################################################################################
# Submitting 158: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-FLK_PPO_1.sh
# Submitted batch job 40234799
# #########################################################################################
# Submitting 159: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-FLK_PPO_2.sh
# Submitted batch job 40234800
# #########################################################################################
# Submitting 160: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-FLK_PPO_3.sh
# Submitted batch job 40234801
# #########################################################################################
# Submitting 181: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RN_PPO_0.sh
# Submitted batch job 40234802
# #########################################################################################
# Submitting 182: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RN_PPO_1.sh
# Submitted batch job 40234803
# #########################################################################################
# Submitting 183: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RN_PPO_2.sh
# Submitted batch job 40234804
# #########################################################################################
# Submitting 184: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RN_PPO_3.sh
# Submitted batch job 40234805
# #########################################################################################
# Submitting 205: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RSM_PPO_0.sh
# Submitted batch job 40234806
# #########################################################################################
# Submitting 206: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RSM_PPO_1.sh
# Submitted batch job 40234807
# #########################################################################################
# Submitting 207: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RSM_PPO_2.sh
# Submitted batch job 40234808
# #########################################################################################
# Submitting 208: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RSM_PPO_3.sh
# Submitted batch job 40234809
# #########################################################################################
# Submitting 229: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RV_PPO_0.sh
# Submitted batch job 40234810
# #########################################################################################
# Submitting 230: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RV_PPO_1.sh
# Submitted batch job 40234811
# #########################################################################################
# Submitting 231: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RV_PPO_2.sh
# Submitted batch job 40234812
# #########################################################################################
# Submitting 232: /scratch/lingheng/mrl_job_scripts/job_HalfCheetah-v4_POMDP-RV_PPO_3.sh
# Submitted batch job 40234813
# #########################################################################################
# Submitting 253: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_MDP_PPO_0.sh
# Submitted batch job 40234814
# #########################################################################################
# Submitting 254: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_MDP_PPO_1.sh
# Submitted batch job 40234815
# #########################################################################################
# Submitting 255: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_MDP_PPO_2.sh
# Submitted batch job 40234816
# #########################################################################################
# Submitting 256: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_MDP_PPO_3.sh
# Submitted batch job 40234817
# #########################################################################################
# Submitting 277: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-FLK_PPO_0.sh
# Submitted batch job 40234818
# #########################################################################################
# Submitting 278: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-FLK_PPO_1.sh
# Submitted batch job 40234819
# #########################################################################################
# Submitting 279: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-FLK_PPO_2.sh
# Submitted batch job 40234820
# #########################################################################################
# Submitting 280: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-FLK_PPO_3.sh
# Submitted batch job 40234821
# #########################################################################################
# Submitting 301: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RN_PPO_0.sh
# Submitted batch job 40234822
# #########################################################################################
# Submitting 302: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RN_PPO_1.sh
# Submitted batch job 40234823
# #########################################################################################
# Submitting 303: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RN_PPO_2.sh
# Submitted batch job 40234824
# #########################################################################################
# Submitting 304: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RN_PPO_3.sh
# Submitted batch job 40234825
# #########################################################################################
# Submitting 325: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RSM_PPO_0.sh
# Submitted batch job 40234826
# #########################################################################################
# Submitting 326: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RSM_PPO_1.sh
# Submitted batch job 40234827
# #########################################################################################
# Submitting 327: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RSM_PPO_2.sh
# Submitted batch job 40234828
# #########################################################################################
# Submitting 328: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RSM_PPO_3.sh
# Submitted batch job 40234829
# #########################################################################################
# Submitting 349: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RV_PPO_0.sh
# Submitted batch job 40234830
# #########################################################################################
# Submitting 350: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RV_PPO_1.sh
# Submitted batch job 40234831
# #########################################################################################
# Submitting 351: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RV_PPO_2.sh
# Submitted batch job 40234832
# #########################################################################################
# Submitting 352: /scratch/lingheng/mrl_job_scripts/job_Hopper-v4_POMDP-RV_PPO_3.sh
# Submitted batch job 40234833
# #########################################################################################
# Submitting 373: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_MDP_PPO_0.sh
# Submitted batch job 40234834
# #########################################################################################
# Submitting 374: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_MDP_PPO_1.sh
# Submitted batch job 40234835
# #########################################################################################
# Submitting 375: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_MDP_PPO_2.sh
# Submitted batch job 40234836
# #########################################################################################
# Submitting 376: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_MDP_PPO_3.sh
# Submitted batch job 40234838
# #########################################################################################
# Submitting 397: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-FLK_PPO_0.sh
# Submitted batch job 40234839
# #########################################################################################
# Submitting 398: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-FLK_PPO_1.sh
# Submitted batch job 40234840
# #########################################################################################
# Submitting 399: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-FLK_PPO_2.sh
# Submitted batch job 40234842
# #########################################################################################
# Submitting 400: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-FLK_PPO_3.sh
# Submitted batch job 40234843
# #########################################################################################
# Submitting 421: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RN_PPO_0.sh
# Submitted batch job 40234844
# #########################################################################################
# Submitting 422: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RN_PPO_1.sh
# Submitted batch job 40234846
# #########################################################################################
# Submitting 423: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RN_PPO_2.sh
# Submitted batch job 40234847
# #########################################################################################
# Submitting 424: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RN_PPO_3.sh
# Submitted batch job 40234848
# #########################################################################################
# Submitting 445: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RSM_PPO_0.sh
# Submitted batch job 40234849
# #########################################################################################
# Submitting 446: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RSM_PPO_1.sh
# Submitted batch job 40234851
# #########################################################################################
# Submitting 447: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RSM_PPO_2.sh
# Submitted batch job 40234852
# #########################################################################################
# Submitting 448: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RSM_PPO_3.sh
# Submitted batch job 40234853
# #########################################################################################
# Submitting 469: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RV_PPO_0.sh
# Submitted batch job 40234855
# #########################################################################################
# Submitting 470: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RV_PPO_1.sh
# Submitted batch job 40234856
# #########################################################################################
# Submitting 471: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RV_PPO_2.sh
# Submitted batch job 40234858
# #########################################################################################
# Submitting 472: /scratch/lingheng/mrl_job_scripts/job_Walker2d-v4_POMDP-RV_PPO_3.sh
# Submitted batch job 40234859
# #########################################################################################

# %%
job_script_path = os.path.join(job_dir, job_script)
print('Submitting {}: {}'.format(job_i, job_script_path))
# !sbatch {job_script_path}

# %% [markdown]
# ## Resume Experiment

# %%
CPU_NUM = 1
JOB_TIME = '0-12:00'
JOB_MEMORY = '10G'
job_dir = '/scratch/lingheng/mrl_resume_job_scripts'              # job script folder
job_out_dir = '/scratch/lingheng/mrl_resume_job_scripts_output'   # job output folder
data_dir = '/scratch/lingheng/mrl_data'    # experiment data folder

# %%
if not os.path.exists(job_dir):
    os.makedirs(job_dir)
if not os.path.exists(job_out_dir):
    os.makedirs(job_out_dir)

# %%
for exp_run in os.listdir(data_dir):
    if '_gsdata_' in exp_run:
        continue
    # print(exp_run)
    exp_run_inner = os.listdir(os.path.join(data_dir, exp_run))[0]
    progress_file = os.path.join(data_dir, exp_run, exp_run_inner, 'progress.txt')
    if os.path.getsize(progress_file) != 0:
        progress_df = pd.read_csv(progress_file, sep='\t')
        if progress_df.isnull().values.any():
            print(exp_run)
            # break
    # os.path.getsize
# Out:
# 2023-08-03_Ant-v4_POMDP-RSM_LSTM-TD3_3
# 2023-08-03_Walker2d-v4_POMDP-RN_LSTM-TD3_2
# 2023-08-03_Ant-v4_POMDP-RV_LSTM-TD3_3
# 2023-08-03_Walker2d-v4_POMDP-RSM_LSTM-TD3_3
# 2023-08-02_Ant-v4_MDP_LSTM-TD3_0.sh
# 2023-08-03_Walker2d-v4_POMDP-FLK_LSTM-TD3_1
# 2023-08-03_Hopper-v4_MDP_LSTM-TD3_3
# 2023-08-03_Walker2d-v4_POMDP-RV_LSTM-TD3_1
# 2023-08-03_Ant-v4_POMDP-FLK_LSTM-TD3_1
# 2023-08-03_Ant-v4_POMDP-RN_LSTM-TD3_0
# 2023-08-03_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_2
# 2023-08-03_Hopper-v4_POMDP-RSM_LSTM-TD3_3
# 2023-08-03_HalfCheetah-v4_MDP_LSTM-TD3_2
# 2023-08-03_HalfCheetah-v4_POMDP-RN_LSTM-TD3_3
# 2023-08-03_Hopper-v4_POMDP-RN_LSTM-TD3_0
# 2023-08-03_HalfCheetah-v4_POMDP-RV_LSTM-TD3_0
# 2023-08-03_Hopper-v4_POMDP-RV_LSTM-TD3_3
# 2023-08-03_Hopper-v4_POMDP-FLK_LSTM-TD3_1
# 2023-08-03_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_0
# 2023-08-03_Ant-v4_MDP_LSTM-TD3_3
# 2023-08-03_Ant-v4_POMDP-RV_LSTM-TD3_0
# 2023-08-03_Walker2d-v4_POMDP-RN_LSTM-TD3_1
# 2023-08-03_Ant-v4_POMDP-RSM_LSTM-TD3_0
# 2023-08-03_Walker2d-v4_POMDP-RSM_LSTM-TD3_0
# 2023-08-03_Walker2d-v4_POMDP-FLK_LSTM-TD3_2
# 2023-08-03_Ant-v4_POMDP-FLK_LSTM-TD3_2
# 2023-08-03_Ant-v4_POMDP-RN_LSTM-TD3_3
# 2023-08-03_Walker2d-v4_POMDP-RV_LSTM-TD3_2
# 2023-08-03_Hopper-v4_MDP_LSTM-TD3_0
# 2023-08-03_Hopper-v4_POMDP-RN_LSTM-TD3_3
# 2023-08-03_HalfCheetah-v4_POMDP-RN_LSTM-TD3_0
# 2023-08-03_HalfCheetah-v4_MDP_LSTM-TD3_1
# 2023-08-03_Hopper-v4_POMDP-RSM_LSTM-TD3_0
# 2023-08-03_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_1
# 2023-08-03_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_3
# 2023-08-03_Hopper-v4_POMDP-FLK_LSTM-TD3_2
# 2023-08-03_Hopper-v4_POMDP-RV_LSTM-TD3_0
# 2023-08-03_HalfCheetah-v4_POMDP-RV_LSTM-TD3_3
# 2023-08-03_Ant-v4_MDP_LSTM-TD3_0
# 2023-08-03_Hopper-v4_POMDP-RV_LSTM-TD3_2
# 2023-08-03_HalfCheetah-v4_POMDP-RV_LSTM-TD3_1
# 2023-08-03_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_1
# 2023-08-03_Hopper-v4_POMDP-FLK_LSTM-TD3_0
# 2023-08-03_Ant-v4_MDP_LSTM-TD3_2
# 2023-08-03_Hopper-v4_POMDP-RSM_LSTM-TD3_2
# 2023-08-03_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_3
# 2023-08-03_Hopper-v4_POMDP-RN_LSTM-TD3_1
# 2023-08-03_HalfCheetah-v4_POMDP-RN_LSTM-TD3_2
# 2023-08-03_HalfCheetah-v4_MDP_LSTM-TD3_3
# 2023-08-03_Walker2d-v4_POMDP-FLK_LSTM-TD3_0
# 2023-08-03_Hopper-v4_MDP_LSTM-TD3_2
# 2023-08-03_Walker2d-v4_MDP_LSTM-TD3_1
# 2023-08-03_Ant-v4_POMDP-FLK_LSTM-TD3_0
# 2023-08-03_Ant-v4_POMDP-RN_LSTM-TD3_1
# 2023-08-03_Walker2d-v4_POMDP-RV_LSTM-TD3_0
# 2023-08-03_Ant-v4_POMDP-RV_LSTM-TD3_2
# 2023-08-03_Walker2d-v4_POMDP-RN_LSTM-TD3_3
# 2023-08-03_Ant-v4_POMDP-RSM_LSTM-TD3_2
# 2023-08-03_Walker2d-v4_POMDP-RSM_LSTM-TD3_2
# 2023-08-03_Hopper-v4_POMDP-FLK_LSTM-TD3_3
# 2023-08-03_HalfCheetah-v4_POMDP-RSM_LSTM-TD3_2
# 2023-08-03_HalfCheetah-v4_POMDP-RV_LSTM-TD3_2
# 2023-08-03_Hopper-v4_POMDP-RV_LSTM-TD3_1
# 2023-08-03_Ant-v4_MDP_LSTM-TD3_1
# 2023-08-03_HalfCheetah-v4_MDP_LSTM-TD3_0
# 2023-08-03_HalfCheetah-v4_POMDP-RN_LSTM-TD3_1
# 2023-08-03_Hopper-v4_POMDP-RN_LSTM-TD3_2
# 2023-08-03_HalfCheetah-v4_POMDP-FLK_LSTM-TD3_0
# 2023-08-03_Hopper-v4_POMDP-RSM_LSTM-TD3_1
# 2023-08-03_Walker2d-v4_POMDP-FLK_LSTM-TD3_3
# 2023-08-03_Walker2d-v4_POMDP-RV_LSTM-TD3_3
# 2023-08-03_Ant-v4_POMDP-FLK_LSTM-TD3_3
# 2023-08-03_Ant-v4_POMDP-RN_LSTM-TD3_2
# 2023-08-03_Hopper-v4_MDP_LSTM-TD3_1
# 2023-08-03_Ant-v4_POMDP-RSM_LSTM-TD3_1
# 2023-08-03_Walker2d-v4_POMDP-RN_LSTM-TD3_0
# 2023-08-03_Ant-v4_POMDP-RV_LSTM-TD3_1
# 2023-08-03_Walker2d-v4_POMDP-RSM_LSTM-TD3_1

# %%
progress_df
# Out:
#     Epoch  AverageEpHCRet  StdEpHCRet  MaxEpHCRet  MinEpHCRet
# 0       1      -54.682230   80.206633   17.832783  -356.62875  \
# 1       2      -73.242708  132.004403   18.715786  -358.14500
# 2       3             NaN         NaN         NaN         NaN
# 3       4             NaN         NaN         NaN         NaN
# 4       5             NaN         NaN         NaN         NaN
# 5       6             NaN         NaN         NaN         NaN
# 6       7             NaN         NaN         NaN         NaN
# 7       8             NaN         NaN         NaN         NaN
# 8       9             NaN         NaN         NaN         NaN
# 9      10             NaN         NaN         NaN         NaN
# 10     11             NaN         NaN         NaN         NaN
# 11     12             NaN         NaN         NaN         NaN
# 12     13             NaN         NaN         NaN         NaN
# 13     14             NaN         NaN         NaN         NaN
# 14     15             NaN         NaN         NaN         NaN
# 15     16             NaN         NaN         NaN         NaN
# 16     17             NaN         NaN         NaN         NaN
# 17     18             NaN         NaN         NaN         NaN
# 18     19             NaN         NaN         NaN         NaN
# 19     20             NaN         NaN         NaN         NaN
# 20     21             NaN         NaN         NaN         NaN
#
#     AverageTestEpHCRet  StdTestEpHCRet  MaxTestEpHCRet  MinTestEpHCRet
# 0                  NaN             NaN             NaN             NaN  \
# 1                  NaN             NaN             NaN             NaN
# 2                  NaN             NaN             NaN             NaN
# 3                  NaN             NaN             NaN             NaN
# 4                  NaN             NaN             NaN             NaN
# 5                  NaN             NaN             NaN             NaN
# 6                  NaN             NaN             NaN             NaN
# 7                  NaN             NaN             NaN             NaN
# 8                  NaN             NaN             NaN             NaN
# 9                  NaN             NaN             NaN             NaN
# 10                 NaN             NaN             NaN             NaN
# 11                 NaN             NaN             NaN             NaN
# 12                 NaN             NaN             NaN             NaN
# 13                 NaN             NaN             NaN             NaN
# 14                 NaN             NaN             NaN             NaN
# 15                 NaN             NaN             NaN             NaN
# 16                 NaN             NaN             NaN             NaN
# 17                 NaN             NaN             NaN             NaN
# 18                 NaN             NaN             NaN             NaN
# 19                 NaN             NaN             NaN             NaN
# 20                 NaN             NaN             NaN             NaN
#
#     AverageEpOrigHCRet  ...  StdQ1Vals  MaxQ1Vals  MinQ1Vals  AverageQ2Vals
# 0           -54.682230  ...        NaN        NaN        NaN            NaN  \
# 1           -73.242708  ...        NaN        NaN        NaN            NaN
# 2                  NaN  ...        NaN        NaN        NaN            NaN
# 3                  NaN  ...        NaN        NaN        NaN            NaN
# 4                  NaN  ...        NaN        NaN        NaN            NaN
# 5                  NaN  ...        NaN        NaN        NaN            NaN
# 6                  NaN  ...        NaN        NaN        NaN            NaN
# 7                  NaN  ...        NaN        NaN        NaN            NaN
# 8                  NaN  ...        NaN        NaN        NaN            NaN
# 9                  NaN  ...        NaN        NaN        NaN            NaN
# 10                 NaN  ...        NaN        NaN        NaN            NaN
# 11                 NaN  ...        NaN        NaN        NaN            NaN
# 12                 NaN  ...        NaN        NaN        NaN            NaN
# 13                 NaN  ...        NaN        NaN        NaN            NaN
# 14                 NaN  ...        NaN        NaN        NaN            NaN
# 15                 NaN  ...        NaN        NaN        NaN            NaN
# 16                 NaN  ...        NaN        NaN        NaN            NaN
# 17                 NaN  ...        NaN        NaN        NaN            NaN
# 18                 NaN  ...        NaN        NaN        NaN            NaN
# 19                 NaN  ...        NaN        NaN        NaN            NaN
# 20                 NaN  ...        NaN        NaN        NaN            NaN
#
#     StdQ2Vals  MaxQ2Vals  MinQ2Vals  LossPi  LossQ          Time
# 0         NaN        NaN        NaN     NaN    NaN    266.787010
# 1         NaN        NaN        NaN     NaN    NaN    781.815825
# 2         NaN        NaN        NaN     NaN    NaN   2062.677243
# 3         NaN        NaN        NaN     NaN    NaN   2422.522570
# 4         NaN        NaN        NaN     NaN    NaN   3155.476716
# 5         NaN        NaN        NaN     NaN    NaN   3643.740835
# 6         NaN        NaN        NaN     NaN    NaN   4290.484941
# 7         NaN        NaN        NaN     NaN    NaN   4700.222509
# 8         NaN        NaN        NaN     NaN    NaN   5401.253952
# 9         NaN        NaN        NaN     NaN    NaN   5902.924173
# 10        NaN        NaN        NaN     NaN    NaN   6557.893605
# 11        NaN        NaN        NaN     NaN    NaN   7223.952808
# 12        NaN        NaN        NaN     NaN    NaN   7664.494416
# 13        NaN        NaN        NaN     NaN    NaN   8042.177555
# 14        NaN        NaN        NaN     NaN    NaN   8407.068466
# 15        NaN        NaN        NaN     NaN    NaN   8872.865023
# 16        NaN        NaN        NaN     NaN    NaN   9250.729562
# 17        NaN        NaN        NaN     NaN    NaN   9654.207959
# 18        NaN        NaN        NaN     NaN    NaN  10074.849950
# 19        NaN        NaN        NaN     NaN    NaN  10535.484681
# 20        NaN        NaN        NaN     NaN    NaN  10972.411329
#
# [21 rows x 39 columns]

# %% [markdown]
# ## Remove PPO with Action Clamp
# Do not run this part again.

# %%
# data_dir = '/scratch/lingheng/mrl_data'    # experiment data folder

# %%
# os.mkdir(os.path.join(data_dir, 'archive_PPO_with_action_clamp'))

# %%
# for exp_run in os.listdir(data_dir):
#     if 'PPO' in exp_run:
#         print(exp_run)
#         shutil.move(os.path.join(data_dir, exp_run), os.path.join(data_dir, 'archive_PPO_with_action_clamp'))
